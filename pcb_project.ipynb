# %%
# -*- coding: utf-8 -*-
"""PCB_Project.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/18ng1uVfH06WUqVbR9llbeKc-i1ibqBoh
"""

import requests
#import os
from datetime import datetime

api_key = '87d845b0b6cf29baa1a73cc34b067a95'
location = input("Enter the city name: ")

complete_api_link = "https://api.openweathermap.org/data/2.5/weather?q="+location+"&appid="+api_key
api_link = requests.get(complete_api_link)
api_data = api_link.json()

#create variables to store and display data
temp_city = ((api_data['main']['temp']) - 273.15)
weather_desc = api_data['weather'][0]['description']
hmdt = api_data['main']['humidity']
wind_spd = api_data['wind']['speed']
date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")

print ("-------------------------------------------------------------")
print ("Weather Stats for - {}  || {}".format(location.upper(), date_time))
print ("-------------------------------------------------------------")

print ("Current temperature is: {:.2f} deg C".format(temp_city))
print ("Current weather desc  :",weather_desc)
print ("Current Humidity      :",hmdt, '%')
print ("Current wind speed    :",wind_spd ,'kmph')

with open('op_example.txt','wt') as t:
  t.write("-------------------------------------------------------------\n")
  t.write("Weather Stats for - {}  || {}\n".format(location.upper(), date_time))
  t.write("-------------------------------------------------------------\n")
  t.write("Current temperature is: {:.2f} deg C\n".format(temp_city))
  t.write("Current weather desc  : {}\n".format(weather_desc))
  t.write("Current Humidity      : {}\n".format(hmdt, '%'))
  t.write("Current wind speed    : {}\n".format(wind_spd ,'kmph'))
# Out:
# Enter the city name: kannur
# -------------------------------------------------------------
# Weather Stats for - KANNUR  || 23 Jun 2021 | 08:51:25 AM
# -------------------------------------------------------------
# Current temperature is: 28.52 deg C
# Current weather desc  : overcast clouds
# Current Humidity      : 76 %
# Current wind speed    : 4.99 kmph
